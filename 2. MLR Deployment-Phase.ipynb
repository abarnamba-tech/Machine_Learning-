# %%
import pickle

# %%
loaded_model=pickle.load(open("finalized_model_linear_of_mlr.sav",'rb'))
result=loaded_model.predict([[285861,58649,22516,0,0]])
result
# Out:
# C:\Users\abarn\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[270943.60055363]])
