# %%
import pickle

# %%
loaded_model=pickle.load(open("random_forest_finalized_model.sav",'rb'))
result=loaded_model.predict([[12845,68894,56483,1,0]])
result
# Out:
# C:\Users\abarn\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# array([66299.3036])
